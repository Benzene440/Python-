# %%
#parvathi poorna question no :5

# %%
#Ktu id:cea20ec016 
    
# Python Program to Count Number of Digits in a Number Using Recursion
Count_ec016= 0
# Define a Recursive function
def Counting(Number_ec016):
    global Count_ec016
    if(Number_ec016 > 0):
        Count_ec016 = Count_ec016 + 1
        Counting(Number_ec016//10)
    return Count_ec016
Number_ec016 = int(input("Enter any Number:number_ec016*4"))
Count_ec016 = Counting(Number_ec016)
print("Number of Digits in a Given Number_ec016 = %d" %Count_ec016)
# Out:
# Enter any Number:number_ec016*42016
# Number of Digits in a Given Number_ec016 = 4

# %%
#number=2016 *4=8064
